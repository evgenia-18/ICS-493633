# %% [markdown]
# <a href="https://colab.research.google.com/github/evgenia-18/ICS-493633/blob/main/Lab11_1_%D0%93%D0%BB%D1%83%D1%88%D0%B0%D0%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Була присутня на парі

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow import keras
import os

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot' ]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
x_train = (x_train / 255.0).astype("float32")
x_test = (x_test / 255.0).astype("float32")

# %%
model = models.Sequential([
    keras.Input(shape=(28, 28)),
    layers. Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=3e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
cb = [
tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True),
tf.keras.callbacks. ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6, verbose=1)
]

history = model.fit(
x_train, y_train,
epochs=50,
batch_size=128,
validation_split=0.1,
callbacks=cb,
verbose=1
)

test_loss, test_acc = model. evaluate(x_test, y_test, verbose=0)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7067 - loss: 0.8645 - val_accuracy: 0.8330 - val_loss: 0.4818 - learning_rate: 3.0000e-04
# Epoch 2/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8152 - loss: 0.5335 - val_accuracy: 0.8463 - val_loss: 0.4177 - learning_rate: 3.0000e-04
# Epoch 3/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8380 - loss: 0.4665 - val_accuracy: 0.8572 - val_loss: 0.3923 - learning_rate: 3.0000e-04
# Epoch 4/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8483 - loss: 0.4293 - val_accuracy: 0.8638 - val_loss: 0.3717 - learning_rate: 3.0000e-04
# Epoch 5/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8569 - loss: 0.4031 - val_accuracy: 0.8717 - val_loss: 0.3570 - learning_rate: 3.0000e-04
# Epoch 6/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8623 - loss: 0.3867 - val_accuracy: 0.8713 - val_loss: 0.3482 - learning_rate: 3.0000e-04
# Epoch 7/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8683 - loss: 0.3709 - val_accuracy: 0.8780 - val_loss: 0.3429 - learning_rate: 3.0000e-04
# Epoch 8/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8733 - loss: 0.3598 - val_accuracy: 0.8742 - val_loss: 0.3369 - learning_rate: 3.0000e-04
# Epoch 9/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8741 - loss: 0.3518 - val_accuracy: 0.8813 - val_loss: 0.3266 - learning_rate: 3.0000e-04
# Epoch 10/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8788 - loss: 0.3401 - val_accuracy: 0.8820 - val_loss: 0.3307 - learning_rate: 3.0000e-04
# Epoch 11/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8808 - loss: 0.3315 - val_accuracy: 0.8805 - val_loss: 0.3240 - learning_rate: 3.0000e-04
# Epoch 12/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8833 - loss: 0.3221 - val_accuracy: 0.8868 - val_loss: 0.3115 - learning_rate: 3.0000e-04
# Epoch 13/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8880 - loss: 0.3129 - val_accuracy: 0.8870 - val_loss: 0.3101 - learning_rate: 3.0000e-04
# Epoch 14/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8893 - loss: 0.3074 - val_accuracy: 0.8885 - val_loss: 0.3117 - learning_rate: 3.0000e-04
# Epoch 15/50
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8916 - loss: 0.2992
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8904 - loss: 0.3040 - val_accuracy: 0.8875 - val_loss: 0.3138 - learning_rate: 3.0000e-04
# Epoch 16/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8962 - loss: 0.2869 - val_accuracy: 0.8902 - val_loss: 0.3001 - learning_rate: 1.5000e-04
# Epoch 17/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8989 - loss: 0.2821 - val_accuracy: 0.8923 - val_loss: 0.2967 - learning_rate: 1.5000e-04
# Epoch 18/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8982 - loss: 0.2779 - val_accuracy: 0.8912 - val_loss: 0.2994 - learning_rate: 1.5000e-04
# Epoch 19/50
# 421/422 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9033 - loss: 0.2714
# Epoch 19: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9015 - loss: 0.2734 - val_accuracy: 0.8887 - val_loss: 0.2982 - learning_rate: 1.5000e-04
# Epoch 20/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9028 - loss: 0.2675 - val_accuracy: 0.8925 - val_loss: 0.2950 - learning_rate: 7.5000e-05
# Epoch 21/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9038 - loss: 0.2630 - val_accuracy: 0.8930 - val_loss: 0.2967 - learning_rate: 7.5000e-05
# Epoch 22/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9048 - loss: 0.2619 - val_accuracy: 0.8908 - val_loss: 0.2945 - learning_rate: 7.5000e-05
# Epoch 23/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9046 - loss: 0.2595 - val_accuracy: 0.8917 - val_loss: 0.2959 - learning_rate: 7.5000e-05
# Epoch 24/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9081 - loss: 0.2574 - val_accuracy: 0.8923 - val_loss: 0.2937 - learning_rate: 7.5000e-05
# Epoch 25/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9070 - loss: 0.2550 - val_accuracy: 0.8930 - val_loss: 0.2941 - learning_rate: 7.5000e-05
# Epoch 26/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9082 - loss: 0.2540 - val_accuracy: 0.8937 - val_loss: 0.2936 - learning_rate: 7.5000e-05
# Epoch 27/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9082 - loss: 0.2525 - val_accuracy: 0.8908 - val_loss: 0.2942 - learning_rate: 7.5000e-05
# Epoch 28/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9091 - loss: 0.2507 - val_accuracy: 0.8943 - val_loss: 0.2895 - learning_rate: 7.5000e-05
# Epoch 29/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9079 - loss: 0.2504 - val_accuracy: 0.8938 - val_loss: 0.2914 - learning_rate: 7.5000e-05
# Epoch 30/50
# 415/422 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9075 - loss: 0.2515
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9080 - loss: 0.2507 - val_accuracy: 0.8963 - val_loss: 0.2904 - learning_rate: 7.5000e-05
# Epoch 31/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9114 - loss: 0.2453 - val_accuracy: 0.8935 - val_loss: 0.2928 - learning_rate: 3.7500e-05
# Epoch 32/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9108 - loss: 0.2435 - val_accuracy: 0.8953 - val_loss: 0.2891 - learning_rate: 3.7500e-05
# Epoch 33/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9121 - loss: 0.2407 - val_accuracy: 0.8952 - val_loss: 0.2907 - learning_rate: 3.7500e-05
# Epoch 34/50
# 421/422 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9123 - loss: 0.2364
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9127 - loss: 0.2400 - val_accuracy: 0.8945 - val_loss: 0.2890 - learning_rate: 3.7500e-05
# Epoch 35/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9118 - loss: 0.2402 - val_accuracy: 0.8940 - val_loss: 0.2890 - learning_rate: 1.8750e-05
# Test accuracy: 0.8885999917984009

# %%
model. summary ()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 654,176 (2.50 MB)
#  Trainable params: 218,058 (851.79 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 436,118 (1.66 MB)

# %%
from google.colab import drive
drive.mount('/content/drive')
model.save('/content/drive/MyDrive/fashion_mnist_model.keras')
# Out:
# Mounted at /content/drive

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss' )
plt.title('Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy' )
plt.plot(history.history['val_accuracy'], label='Test Accuracy' )
plt.title('Accuracy')
plt.grid(True)
plt.legend()

plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
predictions = model.predict(x_test)

predicted_labels = np.argmax(predictions, axis=1)

print(classification_report(y_test, predicted_labels, target_names=class_names))
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.8886 - loss: 0.3132
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.85      0.84      0.85      1000
#      Trouser       0.99      0.97      0.98      1000
#     Pullover       0.80      0.78      0.79      1000
#        Dress       0.88      0.90      0.89      1000
#         Coat       0.80      0.83      0.81      1000
#       Sandal       0.98      0.96      0.97      1000
#        Shirt       0.71      0.71      0.71      1000
#      Sneaker       0.93      0.97      0.95      1000
#          Bag       0.97      0.97      0.97      1000
#   Ankle boot       0.97      0.95      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
plt.figure(figsize=(15, 3))

for i in range(10):
    plt.subplot(1, 10, i +1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap='gray')
    pred_label = class_names[predicted_labels[i]]
    true_label = class_names[y_test[i]]
    color = 'green' if predicted_labels[i] == y_test[i] else 'red'
    plt.xlabel(f"Pred:\n{pred_label}", color=color)
    plt.title(f"True:\n{true_label}", fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# Завдання 2

# %%
# !pip install keras-tuner -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 2.2 MB/s eta 0:00:00

# %%
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from keras_tuner.tuners import RandomSearch

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow import keras
import os

# %%
fashion_mnist = tf.keras.datasets. fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(keras.Input(shape=(28, 28)))
    model.add(Flatten())

    # Тюнінг шарів
    for i in range(hp.Int('num_layers', 1, 3)):
        model.add(Dense(
            units=hp.Int('units_' + str(i),
                         min_value=32,
                         max_value=512,
                         step=32),
            activation='relu',
            kernel_regularizer=l2(0.001)
        ))
        model.add(Dropout(0.2))

    model.add(Dense(10, activation='softmax'))

    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
tuner = RandomSearch(
build_model,
objective='val_accuracy',
max_trials=3,
executions_per_trial=1,
directory='tuner_logs',
project_name='fashion_mnist_classification'

)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

tuner.search(x_train, y_train, epochs=50, validation_data=(x_test, y_test),
callbacks=[early_stopping, reduce_lr])

best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()

history = best_model.fit(
x_train, y_train,
epochs=50,
validation_data=(x_test, y_test),
callbacks=[early_stopping, reduce_lr]
)
# Out:
# Trial 3 Complete [00h 05m 35s]
# val_accuracy: 0.8621000051498413
#
# Best val_accuracy So Far: 0.8621000051498413
# Total elapsed time: 00h 10m 41s
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 320)            │       251,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 320)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 288)            │        92,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 288)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,890 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 346,538 (1.32 MB)
#  Trainable params: 346,538 (1.32 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - accuracy: 0.8492 - loss: 0.5085 - val_accuracy: 0.8481 - val_loss: 0.5207 - learning_rate: 0.0010
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8510 - loss: 0.5092 - val_accuracy: 0.8552 - val_loss: 0.5026 - learning_rate: 0.0010
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.8525 - loss: 0.5031 - val_accuracy: 0.8534 - val_loss: 0.5001 - learning_rate: 0.0010
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8504 - loss: 0.5076 - val_accuracy: 0.8620 - val_loss: 0.4838 - learning_rate: 0.0010
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8515 - loss: 0.5062 - val_accuracy: 0.8277 - val_loss: 0.5532 - learning_rate: 0.0010
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.8515 - loss: 0.5038 - val_accuracy: 0.8555 - val_loss: 0.4837 - learning_rate: 0.0010
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8498 - loss: 0.5027 - val_accuracy: 0.8567 - val_loss: 0.4897 - learning_rate: 0.0010
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8505 - loss: 0.5036 - val_accuracy: 0.8492 - val_loss: 0.5161 - learning_rate: 0.0010
# Epoch 9/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.8503 - loss: 0.5021 - val_accuracy: 0.8592 - val_loss: 0.4771 - learning_rate: 0.0010
# Epoch 10/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.8522 - loss: 0.5023 - val_accuracy: 0.8575 - val_loss: 0.4787 - learning_rate: 0.0010
# Epoch 11/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.8517 - loss: 0.4995 - val_accuracy: 0.8628 - val_loss: 0.4693 - learning_rate: 0.0010
# Epoch 12/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8514 - loss: 0.4985 - val_accuracy: 0.8581 - val_loss: 0.4891 - learning_rate: 0.0010
# Epoch 13/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.8531 - loss: 0.4990 - val_accuracy: 0.8516 - val_loss: 0.5098 - learning_rate: 0.0010
# Epoch 14/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.8516 - loss: 0.5022 - val_accuracy: 0.8534 - val_loss: 0.4990 - learning_rate: 0.0010

# %%
test_loss, test_acc = best_model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training loss' )
plt.plot(history.history['val_loss'], label='Validation loss' )
plt.title('Loss during training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy' ], label='Training accuracy' )
plt.plot(history.history['val_accuracy'], label='Validation accuracy' )
plt.title('Accuracy during training')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8628 - loss: 0.4693
# Test accuracy: 0.8628000020980835
# Test loss: 0.46927011013031006

# %%
Висновок: Виконуючи лабораторну роботу, побудували модель, виведели архітектуру, побудували графіки  та вивели візуалізацію класифікації.
